# %%
import nbimporter
import trajectories, psychometrics, initiation_times, eye_hand_lags
# Out:
# Importing Jupyter notebook from trajectories.ipynb
# Importing Jupyter notebook from psychometrics.ipynb
# Importing Jupyter notebook from initiation_times.ipynb
# Importing Jupyter notebook from eye_hand_lags.ipynb

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import random
import data_reader, data_analyser, trajectory_plotter

dr = data_reader.DataReader()
exp_1, exp_2 = 'Exp 1', 'Exp 2'
choices_1, dynamics_1 = dr.get_data(path='../../data/HEM_exp_1/processed/', rename_vars=True, IT_threshold=1.5)
choices_2, dynamics_2 = dr.get_data(path='../../data/HEM_exp_2/processed/', rename_vars=True, IT_threshold=1.5)
choices = choices_2

# %%
trajectories.plot_example_traj_xy(dynamics_2)
trajectories.plot_example_traj_x(dynamics_2)

# %%
psychometrics.plot_psychometric_function_ci(choices_1, exp_1, n_threshold=0)
psychometrics.plot_psychometric_function_ci(choices_2, exp_2, n_threshold=0)

# %%
labels=['Total','Error','Correct']
# labels=['Total', 'To correct', 'To error']
psychometrics.plot_p_com_ci(choices_1, exp_1, correct_col='is_correct', n_threshold=0, labels=labels)
psychometrics.plot_p_com_ci(choices_2, exp_2, correct_col='is_correct', n_threshold=0, labels=labels)

# %%
psychometrics.plot_p_com_vs_var_ci(choices=choices_1, exp=exp_1, var='hand IT tertile')
psychometrics.plot_p_com_vs_var_ci(choices=choices_2, exp=exp_2, var='hand IT tertile')
psychometrics.plot_p_com_vs_var_ci(choices=choices_1, exp=exp_1, var='eye IT tertile')
psychometrics.plot_p_com_vs_var_ci(choices=choices_2, exp=exp_2, var='eye IT tertile')

# %%
initiation_times.plot_var_grid(choices_1, exp_1, var='hand IT (z)', col='type', hue='choice', 
              hue_order=['Correct', 'Error'],  col_order=['non-CoM', 'CoM'], markers=['o', 'x'], xlabels=False)
initiation_times.plot_var_grid(choices_1, exp_1, var='eye IT (z)', col='type', hue='choice', 
              hue_order=['Correct', 'Error'], col_order=['non-CoM', 'CoM'], markers=['o', 'x'], title=False)

initiation_times.plot_var_grid(choices_2, exp_2, var='hand IT (z)', col='type', hue='choice', 
              hue_order=['Correct', 'Error'], col_order=['non-CoM', 'CoM'], markers=['o', 'x'], xlabels=False)
initiation_times.plot_var_grid(choices_2, exp_2, var='eye IT (z)', col='type', hue='choice', 
              hue_order=['Correct', 'Error'], col_order=['non-CoM', 'CoM'], markers=['o', 'x'], title=False)

# %%
eye_hand_lags.plot_joint(choices_1, exp_1, x='hand IT', y='eye IT')
eye_hand_lags.plot_joint(choices_2, exp_2, x='hand IT', y='eye IT')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
eye_hand_lags.plot_ID_lag_dist(choices_1, choices_2)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
eye_hand_lags.plot_com_lag_dist(choices_1, choices_2)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
